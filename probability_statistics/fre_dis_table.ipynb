# %%
import numpy as np
np.random.seed(45)
import pandas as pd
pd.set_option('display.max_columns', 0)

# %%
data_path = r'C:\Users\DucTRung\Desktop\data_set\statistics'

# %% [markdown]
# ## E.g.1:

# %%
AI_Bundy_f = pd.read_excel(data_path+'\\inferential_statistics_final_exam.xlsx', header=3, usecols='B:O')

# %%
AI_Bundy_f = AI_Bundy_f.rename(columns={'Unnamed: 12': 'Year'})

# %%
AI_Bundy_f
# Out:
#        InvoiceNo                Date         Country  ProductID  Shop  ... UnitPrice  Discount  Year  Month  SalePrice
# 0          52389 2014-01-01 01:06:24  United Kingdom       2152   UK2  ...       159       0.0  2014      1      159.0
# 1          52390 2014-01-01 03:44:48   United States       2230  US15  ...       199       0.2  2014      1      159.2
# 2          52391 2014-01-01 09:01:36          Canada       2160  CAN7  ...       149       0.2  2014      1      119.2
# 3          52392 2014-01-01 09:16:00   United States       2234   US6  ...       159       0.0  2014      1      159.0
# 4          52393 2014-01-01 13:35:12  United Kingdom       2222   UK4  ...       159       0.0  2014      1      159.0
# ...          ...                 ...             ...        ...   ...  ...       ...       ...   ...    ...        ...
# 14962      65773 2016-12-31 13:35:12  United Kingdom       2154   UK2  ...       139       0.0  2016     12      139.0
# ...

# %% [markdown]
# ---------
# ## E.g.2:

# %%
employee_f = pd.read_excel(data_path+'\\Hypothesis_statistics_final_exam.xlsx', header=3, usecols='B:K')

# %%
employee_f
# Out:
#         Surname     Name  Age  Gender  ... Start_date                 Department                      Position    Salary
# 0    Sweetwater     Alex   51    Male  ... 2011-08-15  Software Engineering       Software Engineering Manager   56160.0
# 1      Carabbio   Judith   30  Female  ... 2013-11-11       Software Engineering             Software Engineer  116480.0
# 2         Saada    Adell   31  Female  ... 2012-11-05       Software Engineering             Software Engineer  102440.0
# 3         Szabo   Andrew   34    Male  ... 2014-07-07       Software Engineering             Software Engineer   99840.0
# 4      Andreola    Colby   38  Female  ... 2014-11-10       Software Engineering             Software Engineer   99008.0
# ..          ...      ...  ...     ...  ...        ...                        ...                           ...       ...
# 169        Zima  Colleen   39  Female  ... 2014-09-29          Production              Production Technician I   31200.0
# ...

# %% [markdown]
# ### White vs Nonwhite

# %%
white_f = employee_f[employee_f['Ethnicity'] == 'White'].reset_index()

# %%
nonwhite_f = employee_f[employee_f['Ethnicity'] != 'White'].reset_index()

# %% [markdown]
# ### White vs Nonwhite (with lower and higher 30 year old)

# %%
nonwhite_30_l_f = nonwhite_f[nonwhite_f['Age'] <= 30]

# %%
nonwhite_30_h_f = nonwhite_f[nonwhite_f['Age'] > 30]

# %%
white_30_l_f = white_f[white_f['Age'] <= 30]
white_30_h_f = white_f[white_f['Age'] > 30]

# %%
white_30_h_f
# Out:
#      index       Surname        Name  Age  ... Start_date                 Department                      Position    Salary
# 0        0    Sweetwater        Alex   51  ... 2011-08-15  Software Engineering       Software Engineering Manager   56160.0
# 2        2         Saada       Adell   31  ... 2012-11-05       Software Engineering             Software Engineer  102440.0
# 3        3         Szabo      Andrew   34  ... 2014-07-07       Software Engineering             Software Engineer   99840.0
# 4        4      Andreola       Colby   38  ... 2014-11-10       Software Engineering             Software Engineer   99008.0
# 6        6      Houlihan       Debra   51  ... 2014-05-05                      Sales             Director of Sales  124800.0
# ..     ...           ...         ...  ...  ...        ...                        ...                           ...       ...
# ...

# %% [markdown]
# ### White vs Nonwhite (with difference 'gender')

# %%
white_f[white_f['Gender'] == 'Male']
# Out:
#      index     Surname         Name  Age  ... Start_date                 Department                      Position    Salary
# 0        0  Sweetwater         Alex   51  ... 2011-08-15  Software Engineering       Software Engineering Manager   56160.0
# 3        3       Szabo       Andrew   34  ... 2014-07-07       Software Engineering             Software Engineer   99840.0
# 8        8      Jeremy        Peter   43  ... 2014-05-12                      Sales            Area Sales Manager  116480.0
# 9        9    Gonzales      Ricardo   63  ... 2014-05-12                      Sales            Area Sales Manager  115440.0
# 10      10        Buck       Edward   42  ... 2014-09-29                      Sales            Area Sales Manager  114400.0
# 15      15    Khemmich  Bartholemew   38  ... 2013-08-19                      Sales            Area Sales Manager  114400.0
# ...

# %%
grouped = employee_f['Salary'].groupby([employee_f['Ethnicity'] == 'White', employee_f['Gender'] == 'Male', employee_f['Age'] <= 30])

# %%
grouped.sem()
# Out:
# Ethnicity  Gender  Age
# False      False   False     6179.015905
#                    True     10274.086586
#            True    False     8230.673838
#                    True     10498.120467
# True       False   False     4761.480587
#                    True      9449.510933
#            True    False     5292.165796
#                    True      9806.439608
# Name: Salary, dtype: float64
